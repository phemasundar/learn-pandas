# 38   39       1/23/2020           Anhui  Mainland China  1/23/2020 17:00
# 39   40       1/23/2020         Beijing  Mainland China  1/23/2020 17:00
# 40   41       1/23/2020       Chongqing  Mainland China  1/23/2020 17:00
# 41   42       1/23/2020          Fujian  Mainland China  1/23/2020 17:00
# 42   43       1/23/2020           Gansu  Mainland China  1/23/2020 17:00
# 43   44       1/23/2020       Guangdong  Mainland China  1/23/2020 17:00
# 44   45       1/23/2020         Guangxi  Mainland China  1/23/2020 17:00
# 45   46       1/23/2020         Guizhou  Mainland China  1/23/2020 17:00
# 46   47       1/23/2020          Hainan  Mainland China  1/23/2020 17:00
# 47   48       1/23/2020           Hebei  Mainland China  1/23/2020 17:00
# 48   49       1/23/2020    Heilongjiang  Mainland China  1/23/2020 17:00
# 49   50       1/23/2020           Henan  Mainland China  1/23/2020 17:00
#
#     Confirmed  Deaths  Recovered
# 0           1       0          0
# 1          14       0          0
# 2           6       0          0
# 3           1       0          0
# 4           0       0          0
# 5          26       0          0
# 6           2       0          0
# 7           1       0          0
# 8           4       0          0
# 9           1       0          0
# 10          0       0          0
# 11          5       0          0
# 12          0       0          0
# 13        444      17         28
# 14          4       0          0
# 15          0       0          0
# 16          1       0          0
# 17          2       0          0
# 18          0       0          0
# 19          2       0          0
# 20          1       0          0
# 21          1       0          0
# 22          0       0          0
# 23          0       0          0
# 24          2       0          0
# 25          9       0          0
# 26          1       0          0
# 27          5       0          0
# 28          1       0          0
# 29          4       0          0
# 30          0       0          0
# 31          1       0          0
# 32          0       0          0
# 33          1       0          0
# 34         10       0          0
# 35          2       0          0
# 36          2       0          0
# 37          1       0          0
# 38          9       0          0
# 39         22       0          0
# 40          9       0          0
# 41          5       0          0
# 42          2       0          0
# 43         32       0          2
# 44          5       0          0
# 45          3       0          0
# 46          5       0          0
# 47          1       1          0
# 48          2       0          0
# 49          5       0          0

# %%
df.drop(["SNo", "Last Update"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   ObservationDate Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0       1/22/2020          Anhui  Mainland China          1       0          0
# 1       1/22/2020        Beijing  Mainland China         14       0          0
# 2       1/22/2020      Chongqing  Mainland China          6       0          0
# 3       1/22/2020         Fujian  Mainland China          1       0          0
# 4       1/22/2020          Gansu  Mainland China          0       0          0

# %%
df.rename(columns={"ObservationDate": "Date", "Province/State": "State", "Country/Region": "Country"}, inplace=True)

# %%
df.head()
# Out:
#         Date      State         Country  Confirmed  Deaths  Recovered
# 0  1/22/2020      Anhui  Mainland China          1       0          0
# 1  1/22/2020    Beijing  Mainland China         14       0          0
# 2  1/22/2020  Chongqing  Mainland China          6       0          0
# 3  1/22/2020     Fujian  Mainland China          1       0          0
# 4  1/22/2020      Gansu  Mainland China          0       0          0

# %%
df.describe()
# Out:
#         Confirmed     Deaths  Recovered
# count   50.000000  50.000000  50.000000
# mean    13.100000   0.360000   0.600000
# std     62.526158   2.405436   3.964125
# min      0.000000   0.000000   0.000000
# 25%      1.000000   0.000000   0.000000
# 50%      2.000000   0.000000   0.000000
# 75%      5.000000   0.000000   0.000000
# max    444.000000  17.000000  28.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date
# 40  1/23/2020       Chongqing  Mainland China          9       0          0
# 41  1/23/2020          Fujian  Mainland China          5       0          0
# 42  1/23/2020           Gansu  Mainland China          2       0          0
# 43  1/23/2020       Guangdong  Mainland China         32       0          2
# 44  1/23/2020         Guangxi  Mainland China          5       0          0
# 45  1/23/2020         Guizhou  Mainland China          3       0          0
# 46  1/23/2020          Hainan  Mainland China          5       0          0
# 47  1/23/2020           Hebei  Mainland China          1       1          0
# 48  1/23/2020    Heilongjiang  Mainland China          2       0          0
# 49  1/23/2020           Henan  Mainland China          5       0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       50 non-null     object
#  1   State      47 non-null     object
#  2   Country    50 non-null     object
#  3   Confirmed  50 non-null     int64
#  4   Deaths     50 non-null     int64
#  5   Recovered  50 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
df2 = df.groupby('Country')[['Country','Confirmed','Deaths','Recovered']].sum().reset_index();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hc/jr3jp1392mzfjfkrlqwzg1s80000gq/T/ipykernel_32055/3956984530.py in ?()
# ----> 1 df2 = df.groupby('Country')[['Country','Confirmed','Deaths','Recovered']].sum().reset_index();
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6219                     level_values = algorithms.take(
#    6220                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6221                     )
#    6222
# -> 6223                 new_obj.insert(
#    6224                     0,
#    6225                     name,
#    6226                     level_values,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    4930                 "'self.flags.allows_duplicate_labels' is False."
#    4931             )
#    4932         if not allow_duplicates and column in self.columns:
#    4933             # Should this be a different kind of error??
# -> 4934             raise ValueError(f"cannot insert {column}, already exists")
#    4935         if not is_integer(loc):
#    4936             raise TypeError("loc must be int")
#    4937         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Country, already exists

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df2 = df.groupby(['Country','Date'])[['Country','Date','Confirmed','Deaths','Recovered']].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hc/jr3jp1392mzfjfkrlqwzg1s80000gq/T/ipykernel_32055/2448502256.py in ?()
# ----> 1 df2 = df.groupby(['Country','Date'])[['Country','Date','Confirmed','Deaths','Recovered']].sum().reset_index()
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6219                     level_values = algorithms.take(
#    6220                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6221                     )
#    6222
# -> 6223                 new_obj.insert(
#    6224                     0,
#    6225                     name,
#    6226                     level_values,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    4930                 "'self.flags.allows_duplicate_labels' is False."
#    4931             )
#    4932         if not allow_duplicates and column in self.columns:
#    4933             # Should this be a different kind of error??
# -> 4934             raise ValueError(f"cannot insert {column}, already exists")
#    4935         if not is_integer(loc):
#    4936             raise TypeError("loc must be int")
#    4937         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Date, already exists

# %%
df3 = df2[df2['Confirmed']>100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df3 = df2[df2['Confirmed']>100]
#
# NameError: name 'df2' is not defined
